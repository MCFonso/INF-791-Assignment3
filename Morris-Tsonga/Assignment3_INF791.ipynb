# %%
#CELL 1 - Setup Instructions
print("📋 INF-791 Assignment 3 - Google Cloud Translate Integration")
print("=" * 60)
print("")
print("🔧 SETUP REQUIRED:")
print("1. Install Google Cloud Translate: ✅ COMPLETED")
print("   python3 -m pip install google-cloud-translate --break-system-packages")
print("")
print("2. Place your service account key file in this directory:")
print("   Expected file: skillful-hope-475413-d0-e1cdda43a60f.json")
print("   Current directory: /home/morris/Downloads/Projects/MyPart/INF-791-Assignment3/Morris-Tsonga/")
print("   🔒 Security: This file is protected by .gitignore")
print("")
print("3. The notebook is configured to use this key automatically")
print("4. Run all cells to test the translation")
print("")
print("📚 Cells Overview:")
print("   Cell 1: This setup information")
print("   Cell 2: Read Excel data file")
print("   Cell 3: Google Cloud Translate API setup")
print("   Cell 4: Authentication configuration")
print("   Cell 5: Test with your exact JSON format ⭐ NEW!")
print("   Cell 6: Translate all French → English & save CSV ⭐ NEW!")
print("   Cell 7: Translate all English → Tsonga & save CSV ⭐ NEW!")
print("")
print("🚀 Ready to begin! Run the cells in order.")
print("=" * 60)
# Out:
# 📋 INF-791 Assignment 3 - Google Cloud Translate Integration
# ============================================================
#
# 🔧 SETUP REQUIRED:
# 1. Install Google Cloud Translate: ✅ COMPLETED
#    python3 -m pip install google-cloud-translate --break-system-packages
#
# 2. Place your service account key file in this directory:
#    Expected file: skillful-hope-475413-d0-e1cdda43a60f.json
#    Current directory: /home/morris/Downloads/Projects/MyPart/INF-791-Assignment3/Morris-Tsonga/
#    🔒 Security: This file is protected by .gitignore
#
# 3. The notebook is configured to use this key automatically
# 4. Run all cells to test the translation
#
# 📚 Cells Overview:
#    Cell 1: This setup information
#    Cell 2: Read Excel data file
#    Cell 3: Google Cloud Translate API setup
#    Cell 4: Authentication configuration
#    Cell 5: Test with your exact JSON format ⭐ NEW!
#    Cell 6: Translate all French → English & save CSV ⭐ NEW!
#    Cell 7: Translate all English → Tsonga & save CSV ⭐ NEW!
#
# 🚀 Ready to begin! Run the cells in order.
# ============================================================

# %%
#CELL 2
import pandas as pd

# Read the Excel file (updated path since we're now in Morris-Tsonga folder)
df = pd.read_excel('../lexicon_6000 words.xlsx')

# Display basic information about the dataset
print(f"Dataset shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
print("\nFirst few rows:")
print(df.head())
# Out:
# Dataset shape: (6963, 7)
# Columns: ['CILUBA', 'French', 'Afrikaans', 'Zulu', 'Score', 'Sentiment', 'Nature']
#
# First few rows:
#       CILUBA     French    Afrikaans              Zulu  Score Sentiment Nature
# 0      Akaja    Arrange     Rangskik             Hlela    1.0   Positif  Verbe
# 1  Akajilula  Rearrange  Herrangskik     Hlela kabusha    1.0   Positif  Verbe
# 2      Akula      Parle        Praat        Uyakhuluma    2.0   Positif  Verbe
# 3    Akulula    Reparle        Praat  Iphinde ikhulume    2.0   Positif  Verbe
# 4      Aluja      Remet        Hande        Isaphulelo    3.0   Positif  Verbe

# %%
#CELL 3 - Google Cloud Translate API
import os

# Try to import Google Cloud Translate with helpful error message
try:
    from google.cloud import translate_v2 as translate
    print("✅ Google Cloud Translate imported successfully!")
    print(f"   Module location: {translate.__file__}")

    # Test that we can create a client (without authentication)
    try:
        # Just test the class exists, don't actually create it yet
        client_class = translate.Client
        print("✅ Translation client class available")
    except Exception as e:
        print(f"⚠️  Warning: Translation client issue: {e}")

except ImportError as e:
    print("❌ Google Cloud Translate not found!")
    print("To fix this issue, try ONE of these solutions:")
    print("")
    print("SOLUTION 1 - Install system-wide (recommended):")
    print("  python3 -m pip install google-cloud-translate --break-system-packages")
    print("")
    print("SOLUTION 2 - Use virtual environment:")
    print("  source venv_gcloud/bin/activate")
    print("  pip install google-cloud-translate")
    print("  # Then restart your Jupyter notebook from within the activated environment")
    print("")
    print("SOLUTION 3 - Install using conda (if you have it):")
    print("  conda install -c conda-forge google-cloud-translate")
    print("")
    print("After installation, restart your Jupyter kernel and try again.")
    raise e

# Set up Google Cloud credentials
service_account_key = 'skillful-hope-475413-d0-e1cdda43a60f.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = service_account_key
print(f"🔐 Authentication configured with: {service_account_key}")

# Project ID
project_id = "projects/skillful-hope-475413-d0"

def translate_text(text, source_language='en', target_language='ts'):
    """
    Translate text using Google Cloud Translate API

    Args:
        text (str or list): Text to translate
        source_language (str): Source language code (default: 'en' for English)
        target_language (str): Target language code (default: 'ts' for Tsonga)

    Returns:
        dict: Translation result
    """
    # Initialize the Translation client
    translate_client = translate.Client()

    # Prepare the request content
    if isinstance(text, str):
        contents = [text]
    elif isinstance(text, list):
        contents = text
    else:
        contents = [str(text)]

    try:
        # Perform the translation
        result = translate_client.translate(
            contents,
            source_language=source_language,
            target_language=target_language
        )

        return result

    except Exception as e:
        print(f"Translation error: {e}")
        return None

# Example usage with your specified content
print("=== Google Cloud Translate API Test ===")

# Your specified translation request
test_content = ["Hello"]
source_lang = "en"
target_lang = "ts"

print(f"Translating: {test_content}")
print(f"From: {source_lang} (English)")
print(f"To: {target_lang} (Tsonga)")
print(f"Project ID: {project_id}")

# Note: To run this cell successfully, you need to:
# 1. Set up authentication by placing your service account JSON file in the project
# 2. Set the GOOGLE_APPLICATION_CREDENTIALS environment variable
# 3. Uncomment and run the translation function below

# Test the translation with your service account
print("\n🚀 Testing translation...")
translation_result = translate_text(test_content, source_lang, target_lang)
if translation_result:
    for i, translation in enumerate(translation_result):
        print(f"Original: {test_content[i]}")
        print(f"Translated: {translation['translatedText']}")
        print(f"Detected source language: {translation.get('detectedSourceLanguage', 'N/A')}")
else:
    print("❌ Translation failed. Check your authentication and API setup.")

print("\n✅ Translation test completed!")
# Out:
# ✅ Google Cloud Translate imported successfully!
#    Module location: /home/morris/.local/lib/python3.13/site-packages/google/cloud/translate_v2/__init__.py
# ✅ Translation client class available
# 🔐 Authentication configured with: skillful-hope-475413-d0-e1cdda43a60f.json
# === Google Cloud Translate API Test ===
# Translating: ['Hello']
# From: en (English)
# To: ts (Tsonga)
# Project ID: projects/skillful-hope-475413-d0
#
# 🚀 Testing translation...
# Original: Hello
# Translated: Avuxeni
# Detected source language: N/A
#
# ✅ Translation test completed!

# %%
#CELL 4 - Authentication Setup (Run this first)
import os
import json

def setup_gcloud_auth(service_account_path=None):
    """
    Setup Google Cloud authentication

    Args:
        service_account_path (str): Path to your service account JSON file
    """

    print("=== Google Cloud Authentication Setup ===")

    if service_account_path and os.path.exists(service_account_path):
        # Set the environment variable for authentication
        os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = service_account_path
        print(f"✅ Authentication set up with service account: {service_account_path}")

        # Verify the service account file
        try:
            with open(service_account_path, 'r') as f:
                service_account = json.load(f)
                print(f"   Project ID: {service_account.get('project_id', 'Not found')}")
                print(f"   Client email: {service_account.get('client_email', 'Not found')}")
        except Exception as e:
            print(f"⚠️  Warning: Could not read service account file: {e}")

    else:
        print("📋 Authentication Setup Instructions:")
        print("1. Download your service account JSON file from Google Cloud Console")
        print("2. Place it in your project directory (keep it private!)")
        print("3. Update the path below and uncomment the setup line:")
        print("   # setup_gcloud_auth('path/to/your-service-account-key.json')")
        print("")
        print("🔐 Alternative: Set environment variable manually:")
        print("   os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'your-key-file.json'")
        print("")
        print("⚠️  IMPORTANT: Never commit your service account key to version control!")
        print("   Add your key file to .gitignore")

# Set up authentication with your service account key
service_account_key = 'skillful-hope-475413-d0-e1cdda43a60f.json'
setup_gcloud_auth(service_account_key)
# Out:
# === Google Cloud Authentication Setup ===
# ✅ Authentication set up with service account: skillful-hope-475413-d0-e1cdda43a60f.json
#    Project ID: skillful-hope-475413-d0
#    Client email: id-91-assignment@skillful-hope-475413-d0.iam.gserviceaccount.com

# %%
#CELL 5 - Test with Exact JSON Format
import json

# Your specified JSON request format
request_json = {
    "contents": [
        "Hello"
    ],
    "sourceLanguageCode": "en",
    "targetLanguageCode": "ts"
}

print("=== Testing with Your Specified JSON Format ===")
print("Request JSON:")
print(json.dumps(request_json, indent=2))
print()

# Test if the service account key file exists
service_account_key = 'skillful-hope-475413-d0-e1cdda43a60f.json'
if not os.path.exists(service_account_key):
    print(f"❌ Service account key not found: {service_account_key}")
    print("Please place your service account key file in this directory:")
    print(f"   {os.getcwd()}/")
    print("Then run this cell again.")
else:
    print(f"✅ Service account key found: {service_account_key}")

    # Set up authentication
    os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = service_account_key

    try:
        from google.cloud import translate_v2 as translate

        # Create translation client
        translate_client = translate.Client()

        # Extract parameters from your JSON format
        contents = request_json["contents"]
        source_lang = request_json["sourceLanguageCode"]
        target_lang = request_json["targetLanguageCode"]

        print(f"📝 Translating: {contents}")
        print(f"🌍 From: {source_lang} → To: {target_lang}")
        print()

        # Perform translation using your exact parameters
        result = translate_client.translate(
            contents,
            source_language=source_lang,
            target_language=target_lang
        )

        print("🎉 Translation Results:")
        for i, translation in enumerate(result):
            print(f"  Original: '{contents[i]}'")
            print(f"  Translated: '{translation['translatedText']}'")
            if 'detectedSourceLanguage' in translation:
                print(f"  Detected Language: {translation['detectedSourceLanguage']}")
            print()

        # Show the full response format
        print("📋 Full API Response:")
        for i, translation in enumerate(result):
            response_json = {
                "translatedText": translation['translatedText'],
                "detectedSourceLanguage": translation.get('detectedSourceLanguage', source_lang)
            }
            print(json.dumps(response_json, indent=2))

    except Exception as e:
        print(f"❌ Translation error: {e}")
        print("This might be due to:")
        print("  - Authentication issues")
        print("  - API not enabled")
        print("  - Network connectivity")
        print("  - Invalid language code")

print("\n" + "="*50)
# Out:
# === Testing with Your Specified JSON Format ===
# Request JSON:
# {
#   "contents": [
#     "Hello"
#   ],
#   "sourceLanguageCode": "en",
#   "targetLanguageCode": "ts"
# }
#
# ✅ Service account key found: skillful-hope-475413-d0-e1cdda43a60f.json
# 📝 Translating: ['Hello']
# 🌍 From: en → To: ts
#
# 🎉 Translation Results:
#   Original: 'Hello'
#   Translated: 'Avuxeni'
#
# 📋 Full API Response:
# {
#   "translatedText": "Avuxeni",
#   "detectedSourceLanguage": "en"
# }
#
# ==================================================

# %%
#CELL 6 - Translate French to English and Save CSV
import pandas as pd
import os
import json
from google.cloud import translate_v2 as translate
import time

print("=== French to English Translation & CSV Export ===")
print("📊 Processing lexicon data for French → English translation")
print()

# Ensure service account key exists
service_account_key = 'skillful-hope-475413-d0-e1cdda43a60f.json'
if not os.path.exists(service_account_key):
    print(f"❌ Service account key not found: {service_account_key}")
    print("Please place your service account key file in this directory first.")
else:
    print(f"✅ Service account key found: {service_account_key}")

    # Set up authentication
    os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = service_account_key

    try:
        # Initialize translation client
        translate_client = translate.Client()
        print("✅ Google Cloud Translate client initialized")

        # Read the Excel file (updated path since we're now in Morris-Tsonga folder)
        excel_path = '../lexicon_6000 words.xlsx'
        df = pd.read_excel(excel_path)
        print(f"📋 Loaded dataset with {len(df)} rows from {excel_path}")

        # Check if 'French' column exists
        if 'French' not in df.columns:
            print(f"❌ 'French' column not found. Available columns: {list(df.columns)}")
        else:
            print(f"✅ Found 'French' column with {len(df)} entries")

            # Create a copy of the dataframe to work with
            df_translated = df.copy()

            # Get French words for translation
            french_words = df['French'].dropna().tolist()
            print(f"🔤 Found {len(french_words)} French words to translate")

            print("\n🚀 Starting translation process...")
            print("⏳ This may take a few minutes depending on the number of words...")

            # Translate in batches to avoid rate limits
            batch_size = 50  # Translate 50 words at a time
            total_words = len(french_words)
            all_translations = []

            for i in range(0, total_words, batch_size):
                batch_words = french_words[i:i + batch_size]
                batch_end = min(i + batch_size, total_words)

                print(f"📝 Translating batch {i//batch_size + 1}: words {i+1}-{batch_end} of {total_words}")

                try:
                    # Translate batch of words
                    results = translate_client.translate(
                        batch_words,
                        source_language='fr',  # French
                        target_language='en'   # English
                    )

                    # Store results
                    batch_translations = [result['translatedText'] for result in results]
                    all_translations.extend(batch_translations)

                    print(f"   ✅ Batch {i//batch_size + 1} completed successfully")

                    # Add small delay to respect rate limits
                    time.sleep(0.5)

                except Exception as e:
                    print(f"   ⚠️ Error in batch {i//batch_size + 1}: {e}")
                    # Add empty translations for failed batch
                    all_translations.extend([None] * len(batch_words))
                    continue

            print(f"\n✅ Translation completed! Processed {len(all_translations)} translations")

            # Apply translations to the dataframe
            print("📊 Applying translations to dataset...")
            # Ensure we have the right number of translations
            if len(all_translations) == len(df_translated[df_translated['French'].notna()]):
                df_translated.loc[df_translated['French'].notna(), 'English_Translation'] = all_translations
            else:
                print(f"⚠️ Translation count mismatch. Expected {len(df_translated[df_translated['French'].notna()])}, got {len(all_translations)}")
                df_translated['English_Translation'] = None

            # Count successful translations
            successful_translations = df_translated['English_Translation'].notna().sum()
            print(f"✅ Successfully translated {successful_translations} out of {len(df_translated)} entries")

            # Generate filename with timestamp for French to English
            from datetime import datetime
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            output_filename = f"lexicon_french_to_english_{timestamp}.csv"
            output_path = output_filename  # Save in current directory (Morris-Tsonga)

            # Save to CSV
            df_translated.to_csv(output_path, index=False, encoding='utf-8')
            print(f"💾 CSV file saved successfully!")
            print(f"📂 Location: {output_path}")
            print(f"📊 File contains {len(df_translated)} rows and {len(df_translated.columns)} columns")

            # Show sample of translations
            print("\n📋 Sample Translations:")
            print("-" * 50)
            sample_df = df_translated[df_translated['English_Translation'].notna()].head(10)
            for idx, row in sample_df.iterrows():
                french_word = row['French']
                english_word = row['English_Translation']
                print(f"  {french_word:15} → {english_word}")

            if len(sample_df) < len(df_translated):
                print(f"  ... and {len(df_translated) - len(sample_df)} more translations")

            print("\n" + "="*60)
            print("🎉 TRANSLATION COMPLETE!")
            print(f"✅ Translated French words to English")
            print(f"💾 Saved CSV file: {output_path}")
            print(f"📊 Dataset: {len(df_translated)} rows, {len(df_translated.columns)} columns")
            print("="*60)

    except Exception as e:
        print(f"❌ Translation process failed: {e}")
        print("This might be due to:")
        print("  - Authentication issues")
        print("  - Google Translate API not enabled")
        print("  - Network connectivity problems")
        print("  - Rate limiting")
# Out:
# === French to English Translation & CSV Export ===
# 📊 Processing lexicon data for French → English translation
#
# ✅ Service account key found: skillful-hope-475413-d0-e1cdda43a60f.json
# ✅ Google Cloud Translate client initialized
# 📋 Loaded dataset with 6963 rows from ../lexicon_6000 words.xlsx
# ✅ Found 'French' column with 6963 entries
# 🔤 Found 6954 French words to translate
#
# 🚀 Starting translation process...
# ⏳ This may take a few minutes depending on the number of words...
# 📝 Translating batch 1: words 1-50 of 6954
#    ✅ Batch 1 completed successfully
# 📝 Translating batch 2: words 51-100 of 6954
#    ✅ Batch 2 completed successfully
# 📝 Translating batch 3: words 101-150 of 6954
#    ✅ Batch 3 completed successfully
# 📝 Translating batch 4: words 151-200 of 6954
#    ✅ Batch 4 completed successfully
# 📝 Translating batch 5: words 201-250 of 6954
#    ✅ Batch 5 completed successfully
# 📝 Translating batch 6: words 251-300 of 6954
#    ✅ Batch 6 completed successfully
# 📝 Translating batch 7: words 301-350 of 6954
#    ✅ Batch 7 completed successfully
# 📝 Translating batch 8: words 351-400 of 6954
#    ✅ Batch 8 completed successfully
# 📝 Translating batch 9: words 401-450 of 6954
#    ✅ Batch 9 completed successfully
# 📝 Translating batch 10: words 451-500 of 6954
#    ✅ Batch 10 completed successfully
# 📝 Translating batch 11: words 501-550 of 6954
#    ✅ Batch 11 completed successfully
# 📝 Translating batch 12: words 551-600 of 6954
#    ✅ Batch 12 completed successfully
# 📝 Translating batch 13: words 601-650 of 6954
#    ✅ Batch 13 completed successfully
# 📝 Translating batch 14: words 651-700 of 6954
#    ✅ Batch 14 completed successfully
# 📝 Translating batch 15: words 701-750 of 6954
#    ✅ Batch 15 completed successfully
# 📝 Translating batch 16: words 751-800 of 6954
#    ✅ Batch 16 completed successfully
# 📝 Translating batch 17: words 801-850 of 6954
#    ✅ Batch 17 completed successfully
# 📝 Translating batch 18: words 851-900 of 6954
#    ✅ Batch 18 completed successfully
# 📝 Translating batch 19: words 901-950 of 6954
#    ✅ Batch 19 completed successfully
# 📝 Translating batch 20: words 951-1000 of 6954
#    ✅ Batch 20 completed successfully
# 📝 Translating batch 21: words 1001-1050 of 6954
#    ✅ Batch 21 completed successfully
# 📝 Translating batch 22: words 1051-1100 of 6954
#    ✅ Batch 22 completed successfully
# 📝 Translating batch 23: words 1101-1150 of 6954
#    ✅ Batch 23 completed successfully
# 📝 Translating batch 24: words 1151-1200 of 6954
#    ✅ Batch 24 completed successfully
# 📝 Translating batch 25: words 1201-1250 of 6954
#    ✅ Batch 25 completed successfully
# 📝 Translating batch 26: words 1251-1300 of 6954
#    ✅ Batch 26 completed successfully
# 📝 Translating batch 27: words 1301-1350 of 6954
#    ✅ Batch 27 completed successfully
# 📝 Translating batch 28: words 1351-1400 of 6954
#    ✅ Batch 28 completed successfully
# 📝 Translating batch 29: words 1401-1450 of 6954
#    ✅ Batch 29 completed successfully
# 📝 Translating batch 30: words 1451-1500 of 6954
#    ✅ Batch 30 completed successfully
# 📝 Translating batch 31: words 1501-1550 of 6954
#    ✅ Batch 31 completed successfully
# 📝 Translating batch 32: words 1551-1600 of 6954
#    ✅ Batch 32 completed successfully
# 📝 Translating batch 33: words 1601-1650 of 6954
#    ✅ Batch 33 completed successfully
# 📝 Translating batch 34: words 1651-1700 of 6954
#    ✅ Batch 34 completed successfully
# 📝 Translating batch 35: words 1701-1750 of 6954
#    ✅ Batch 35 completed successfully
# 📝 Translating batch 36: words 1751-1800 of 6954
#    ✅ Batch 36 completed successfully
# 📝 Translating batch 37: words 1801-1850 of 6954
#    ✅ Batch 37 completed successfully
# 📝 Translating batch 38: words 1851-1900 of 6954
#    ✅ Batch 38 completed successfully
# 📝 Translating batch 39: words 1901-1950 of 6954
#    ✅ Batch 39 completed successfully
# 📝 Translating batch 40: words 1951-2000 of 6954
#    ✅ Batch 40 completed successfully
# 📝 Translating batch 41: words 2001-2050 of 6954
#    ✅ Batch 41 completed successfully
# 📝 Translating batch 42: words 2051-2100 of 6954
#    ✅ Batch 42 completed successfully
# 📝 Translating batch 43: words 2101-2150 of 6954
#    ✅ Batch 43 completed successfully
# 📝 Translating batch 44: words 2151-2200 of 6954
#    ✅ Batch 44 completed successfully
# 📝 Translating batch 45: words 2201-2250 of 6954
#    ✅ Batch 45 completed successfully
# 📝 Translating batch 46: words 2251-2300 of 6954
#    ✅ Batch 46 completed successfully
# 📝 Translating batch 47: words 2301-2350 of 6954
#    ✅ Batch 47 completed successfully
# 📝 Translating batch 48: words 2351-2400 of 6954
#    ✅ Batch 48 completed successfully
# 📝 Translating batch 49: words 2401-2450 of 6954
#    ✅ Batch 49 completed successfully
# 📝 Translating batch 50: words 2451-2500 of 6954
#    ✅ Batch 50 completed successfully
# 📝 Translating batch 51: words 2501-2550 of 6954
#    ✅ Batch 51 completed successfully
# 📝 Translating batch 52: words 2551-2600 of 6954
#    ✅ Batch 52 completed successfully
# 📝 Translating batch 53: words 2601-2650 of 6954
#    ✅ Batch 53 completed successfully
# 📝 Translating batch 54: words 2651-2700 of 6954
#    ✅ Batch 54 completed successfully
# 📝 Translating batch 55: words 2701-2750 of 6954
#    ✅ Batch 55 completed successfully
# 📝 Translating batch 56: words 2751-2800 of 6954
#    ✅ Batch 56 completed successfully
# 📝 Translating batch 57: words 2801-2850 of 6954
#    ✅ Batch 57 completed successfully
# 📝 Translating batch 58: words 2851-2900 of 6954
#    ✅ Batch 58 completed successfully
# 📝 Translating batch 59: words 2901-2950 of 6954
#    ✅ Batch 59 completed successfully
# 📝 Translating batch 60: words 2951-3000 of 6954
#    ✅ Batch 60 completed successfully
# 📝 Translating batch 61: words 3001-3050 of 6954
#    ✅ Batch 61 completed successfully
# 📝 Translating batch 62: words 3051-3100 of 6954
#    ✅ Batch 62 completed successfully
# 📝 Translating batch 63: words 3101-3150 of 6954
#    ⚠️ Error in batch 63: 400 POST https://translation.googleapis.com/language/translate/v2?prettyPrint=false: Invalid value at 'q[22]' (TYPE_STRING), 144 [{'@type': 'type.googleapis.com/google.rpc.BadRequest', 'fieldViolations': [{'field': 'q[22]', 'description': "Invalid value at 'q[22]' (TYPE_STRING), 144"}]}]
# 📝 Translating batch 64: words 3151-3200 of 6954
#    ✅ Batch 64 completed successfully
# 📝 Translating batch 65: words 3201-3250 of 6954
#    ✅ Batch 65 completed successfully
# 📝 Translating batch 66: words 3251-3300 of 6954
#    ✅ Batch 66 completed successfully
# 📝 Translating batch 67: words 3301-3350 of 6954
#    ✅ Batch 67 completed successfully
# 📝 Translating batch 68: words 3351-3400 of 6954
#    ✅ Batch 68 completed successfully
# 📝 Translating batch 69: words 3401-3450 of 6954
#    ✅ Batch 69 completed successfully
# 📝 Translating batch 70: words 3451-3500 of 6954
#    ✅ Batch 70 completed successfully
# 📝 Translating batch 71: words 3501-3550 of 6954
#    ✅ Batch 71 completed successfully
# 📝 Translating batch 72: words 3551-3600 of 6954
#    ✅ Batch 72 completed successfully
# 📝 Translating batch 73: words 3601-3650 of 6954
#    ✅ Batch 73 completed successfully
# 📝 Translating batch 74: words 3651-3700 of 6954
#    ✅ Batch 74 completed successfully
# 📝 Translating batch 75: words 3701-3750 of 6954
#    ✅ Batch 75 completed successfully
# 📝 Translating batch 76: words 3751-3800 of 6954
#    ✅ Batch 76 completed successfully
# 📝 Translating batch 77: words 3801-3850 of 6954
#    ✅ Batch 77 completed successfully
# 📝 Translating batch 78: words 3851-3900 of 6954
#    ✅ Batch 78 completed successfully
# 📝 Translating batch 79: words 3901-3950 of 6954
#    ✅ Batch 79 completed successfully
# 📝 Translating batch 80: words 3951-4000 of 6954
#    ✅ Batch 80 completed successfully
# 📝 Translating batch 81: words 4001-4050 of 6954
#    ✅ Batch 81 completed successfully
# 📝 Translating batch 82: words 4051-4100 of 6954
#    ✅ Batch 82 completed successfully
# 📝 Translating batch 83: words 4101-4150 of 6954
#    ✅ Batch 83 completed successfully
# 📝 Translating batch 84: words 4151-4200 of 6954
#    ✅ Batch 84 completed successfully
# 📝 Translating batch 85: words 4201-4250 of 6954
#    ✅ Batch 85 completed successfully
# 📝 Translating batch 86: words 4251-4300 of 6954
#    ✅ Batch 86 completed successfully
# 📝 Translating batch 87: words 4301-4350 of 6954
#    ✅ Batch 87 completed successfully
# 📝 Translating batch 88: words 4351-4400 of 6954
#    ✅ Batch 88 completed successfully
# 📝 Translating batch 89: words 4401-4450 of 6954
#    ✅ Batch 89 completed successfully
# 📝 Translating batch 90: words 4451-4500 of 6954
#    ✅ Batch 90 completed successfully
# 📝 Translating batch 91: words 4501-4550 of 6954
#    ✅ Batch 91 completed successfully
# 📝 Translating batch 92: words 4551-4600 of 6954
#    ✅ Batch 92 completed successfully
# 📝 Translating batch 93: words 4601-4650 of 6954
#    ✅ Batch 93 completed successfully
# 📝 Translating batch 94: words 4651-4700 of 6954
#    ✅ Batch 94 completed successfully
# 📝 Translating batch 95: words 4701-4750 of 6954
#    ✅ Batch 95 completed successfully
# 📝 Translating batch 96: words 4751-4800 of 6954
#    ✅ Batch 96 completed successfully
# 📝 Translating batch 97: words 4801-4850 of 6954
#    ✅ Batch 97 completed successfully
# 📝 Translating batch 98: words 4851-4900 of 6954
#    ✅ Batch 98 completed successfully
# 📝 Translating batch 99: words 4901-4950 of 6954
#    ✅ Batch 99 completed successfully
# 📝 Translating batch 100: words 4951-5000 of 6954
#    ✅ Batch 100 completed successfully
# 📝 Translating batch 101: words 5001-5050 of 6954
#    ✅ Batch 101 completed successfully
# 📝 Translating batch 102: words 5051-5100 of 6954
#    ✅ Batch 102 completed successfully
# 📝 Translating batch 103: words 5101-5150 of 6954
#    ✅ Batch 103 completed successfully
# 📝 Translating batch 104: words 5151-5200 of 6954
#    ✅ Batch 104 completed successfully
# 📝 Translating batch 105: words 5201-5250 of 6954
#    ✅ Batch 105 completed successfully
# 📝 Translating batch 106: words 5251-5300 of 6954
#    ✅ Batch 106 completed successfully
# 📝 Translating batch 107: words 5301-5350 of 6954
#    ✅ Batch 107 completed successfully
# 📝 Translating batch 108: words 5351-5400 of 6954
#    ✅ Batch 108 completed successfully
# 📝 Translating batch 109: words 5401-5450 of 6954
#    ✅ Batch 109 completed successfully
# 📝 Translating batch 110: words 5451-5500 of 6954
#    ✅ Batch 110 completed successfully
# 📝 Translating batch 111: words 5501-5550 of 6954
#    ✅ Batch 111 completed successfully
# 📝 Translating batch 112: words 5551-5600 of 6954
#    ✅ Batch 112 completed successfully
# 📝 Translating batch 113: words 5601-5650 of 6954
#    ✅ Batch 113 completed successfully
# 📝 Translating batch 114: words 5651-5700 of 6954
#    ✅ Batch 114 completed successfully
# 📝 Translating batch 115: words 5701-5750 of 6954
#    ✅ Batch 115 completed successfully
# 📝 Translating batch 116: words 5751-5800 of 6954
#    ✅ Batch 116 completed successfully
# 📝 Translating batch 117: words 5801-5850 of 6954
#    ✅ Batch 117 completed successfully
# 📝 Translating batch 118: words 5851-5900 of 6954
#    ✅ Batch 118 completed successfully
# 📝 Translating batch 119: words 5901-5950 of 6954
#    ✅ Batch 119 completed successfully
# 📝 Translating batch 120: words 5951-6000 of 6954
#    ✅ Batch 120 completed successfully
# 📝 Translating batch 121: words 6001-6050 of 6954
#    ✅ Batch 121 completed successfully
# 📝 Translating batch 122: words 6051-6100 of 6954
#    ✅ Batch 122 completed successfully
# 📝 Translating batch 123: words 6101-6150 of 6954
#    ✅ Batch 123 completed successfully
# 📝 Translating batch 124: words 6151-6200 of 6954
#    ✅ Batch 124 completed successfully
# 📝 Translating batch 125: words 6201-6250 of 6954
#    ✅ Batch 125 completed successfully
# 📝 Translating batch 126: words 6251-6300 of 6954
#    ✅ Batch 126 completed successfully
# 📝 Translating batch 127: words 6301-6350 of 6954
#    ✅ Batch 127 completed successfully
# 📝 Translating batch 128: words 6351-6400 of 6954
#    ✅ Batch 128 completed successfully
# 📝 Translating batch 129: words 6401-6450 of 6954
#    ✅ Batch 129 completed successfully
# 📝 Translating batch 130: words 6451-6500 of 6954
#    ✅ Batch 130 completed successfully
# 📝 Translating batch 131: words 6501-6550 of 6954
#    ✅ Batch 131 completed successfully
# 📝 Translating batch 132: words 6551-6600 of 6954
#    ✅ Batch 132 completed successfully
# 📝 Translating batch 133: words 6601-6650 of 6954
#    ✅ Batch 133 completed successfully
# 📝 Translating batch 134: words 6651-6700 of 6954
#    ✅ Batch 134 completed successfully
# 📝 Translating batch 135: words 6701-6750 of 6954
#    ✅ Batch 135 completed successfully
# 📝 Translating batch 136: words 6751-6800 of 6954
#    ✅ Batch 136 completed successfully
# 📝 Translating batch 137: words 6801-6850 of 6954
#    ⚠️ Error in batch 137: 400 POST https://translation.googleapis.com/language/translate/v2?prettyPrint=false: Invalid value at 'q[1]' (TYPE_STRING), false [{'@type': 'type.googleapis.com/google.rpc.BadRequest', 'fieldViolations': [{'field': 'q[1]', 'description': "Invalid value at 'q[1]' (TYPE_STRING), false"}]}]
# 📝 Translating batch 138: words 6851-6900 of 6954
#    ✅ Batch 138 completed successfully
# 📝 Translating batch 139: words 6901-6950 of 6954
#    ✅ Batch 139 completed successfully
# 📝 Translating batch 140: words 6951-6954 of 6954
#    ✅ Batch 140 completed successfully
#
# ✅ Translation completed! Processed 6954 translations
# 📊 Applying translations to dataset...
# ✅ Successfully translated 6854 out of 6963 entries
# 💾 CSV file saved successfully!
# 📂 Location: lexicon_french_to_english_20251103_191317.csv
# 📊 File contains 6963 rows and 8 columns
#
# 📋 Sample Translations:
# --------------------------------------------------
#   Arrange         → Arrange
#   Rearrange       → Rearrange
#   Parle           → Speak
#   Reparle         → Speak again
#   Remet           → Hand over
#   Dis             → Say
#   Supperpose      → Superpose
#   Ramasse         → Pick up
#   Depeche         → News report
#   Repete          → Repeated
#   ... and 6953 more translations
#
# ============================================================
# 🎉 TRANSLATION COMPLETE!
# ✅ Translated French words to English
# 💾 Saved CSV file: lexicon_french_to_english_20251103_191317.csv
# 📊 Dataset: 6963 rows, 8 columns
# ============================================================

# %%
#CELL 7 - Translate English to Tsonga and Save CSV
import pandas as pd
import os
import json
from google.cloud import translate_v2 as translate
import time

print("=== English to Tsonga Translation & CSV Export ===")
print("📊 Processing lexicon data for English → Tsonga translation")
print()

# Ensure service account key exists
service_account_key = 'skillful-hope-475413-d0-e1cdda43a60f.json'
if not os.path.exists(service_account_key):
    print(f"❌ Service account key not found: {service_account_key}")
    print("Please place your service account key file in this directory first.")
else:
    print(f"✅ Service account key found: {service_account_key}")

    # Set up authentication
    os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = service_account_key

    try:
        # Initialize translation client
        translate_client = translate.Client()
        print("✅ Google Cloud Translate client initialized")

        # Find the most recent French-to-English CSV file
        import glob
        csv_pattern = 'lexicon_french_to_english_*.csv'
        csv_files = glob.glob(csv_pattern)

        if not csv_files:
            print(f"❌ No French-to-English CSV files found matching pattern: {csv_pattern}")
            print("Please run Cell 6 first to generate the French-to-English translations.")
            raise FileNotFoundError("Source CSV file not found")

        # Use the most recent file
        latest_csv = max(csv_files, key=os.path.getctime)
        print(f"📋 Using source file: {latest_csv}")

        # Read the CSV file with French-to-English translations
        df = pd.read_csv(latest_csv)
        print(f"📋 Loaded dataset with {len(df)} rows from {latest_csv}")

        # Check if 'English_Translation' column exists (from previous French-to-English step)
        if 'English_Translation' not in df.columns:
            print(f"❌ 'English_Translation' column not found. Available columns: {list(df.columns)}")
            print("This suggests the source file doesn't contain French-to-English translations.")
            print("Please run Cell 6 first to generate the French-to-English translations.")
        else:
            print(f"✅ Found 'English_Translation' column with {len(df)} entries")
            print("🔗 Using English translations from French as source for Tsonga translation")

            # Create a copy of the dataframe to work with
            df_translated = df.copy()

            # Get English words from the translation column
            english_words = df['English_Translation'].dropna().tolist()
            print(f"🔤 Found {len(english_words)} English words to translate")
            print(f"📊 These are derived from French-to-English translations")

            print("\n🚀 Starting translation process...")
            print("⏳ This may take a few minutes depending on the number of words...")

            # Translate in batches to avoid rate limits
            batch_size = 50  # Translate 50 words at a time
            total_words = len(english_words)
            all_translations = []

            for i in range(0, total_words, batch_size):
                batch_words = english_words[i:i + batch_size]
                batch_end = min(i + batch_size, total_words)

                print(f"📝 Translating batch {i//batch_size + 1}: words {i+1}-{batch_end} of {total_words}")

                try:
                    # Translate batch of words
                    results = translate_client.translate(
                        batch_words,
                        source_language='en',  # English
                        target_language='ts'   # Tsonga
                    )

                    # Store results
                    batch_translations = [result['translatedText'] for result in results]
                    all_translations.extend(batch_translations)

                    print(f"   ✅ Batch {i//batch_size + 1} completed successfully")

                    # Add small delay to respect rate limits
                    time.sleep(0.5)

                except Exception as e:
                    print(f"   ⚠️ Error in batch {i//batch_size + 1}: {e}")
                    # Add empty translations for failed batch
                    all_translations.extend([None] * len(batch_words))
                    continue

            print(f"\n✅ Translation completed! Processed {len(all_translations)} translations")

            # Apply translations to the dataframe
            print("📊 Applying translations to dataset...")
            # Ensure we have the right number of translations
            if len(all_translations) == len(df_translated[df_translated['English_Translation'].notna()]):
                df_translated.loc[df_translated['English_Translation'].notna(), 'Tsonga_Translation'] = all_translations
            else:
                print(f"⚠️ Translation count mismatch. Expected {len(df_translated[df_translated['English_Translation'].notna()])}, got {len(all_translations)}")
                df_translated['Tsonga_Translation'] = None

            # Count successful translations
            successful_translations = df_translated['Tsonga_Translation'].notna().sum()
            print(f"✅ Successfully translated {successful_translations} out of {len(df_translated)} entries")

            # Generate filename with timestamp for English to Tsonga
            from datetime import datetime
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            output_filename = f"lexicon_english_to_tsonga_{timestamp}.csv"
            output_path = output_filename  # Save in current directory (Morris-Tsonga)

            # Save to CSV
            df_translated.to_csv(output_path, index=False, encoding='utf-8')
            print(f"💾 CSV file saved successfully!")
            print(f"📂 Location: {output_path}")
            print(f"📊 File contains {len(df_translated)} rows and {len(df_translated.columns)} columns")

            # Show sample of translations (French → English → Tsonga chain)
            print("\n📋 Sample Translation Chain (French → English → Tsonga):")
            print("-" * 70)
            sample_df = df_translated[df_translated['Tsonga_Translation'].notna()].head(10)
            for idx, row in sample_df.iterrows():
                french_word = row['French']
                english_word = row['English_Translation']
                tsonga_word = row['Tsonga_Translation']
                print(f"  {french_word:12} → {english_word:15} → {tsonga_word}")

            if len(sample_df) < len(df_translated):
                print(f"  ... and {len(df_translated) - len(sample_df)} more translations")

            print("\n" + "="*60)
            print("🎉 TRANSLATION CHAIN COMPLETE!")
            print(f"✅ French → English → Tsonga translation chain completed")
            print(f"💾 Saved CSV file: {output_path}")
            print(f"📊 Dataset: {len(df_translated)} rows, {len(df_translated.columns)} columns")
            print(f"🔗 Final CSV contains: French, English, English_Translation, Tsonga_Translation")
            print("="*60)

    except Exception as e:
        print(f"❌ Translation process failed: {e}")
        print("This might be due to:")
        print("  - Authentication issues")
        print("  - Google Translate API not enabled")
        print("  - Network connectivity problems")
        print("  - Rate limiting")
        print("  - Tsonga language support limitations")
# Out:
# === English to Tsonga Translation & CSV Export ===
# 📊 Processing lexicon data for English → Tsonga translation
#
# ✅ Service account key found: skillful-hope-475413-d0-e1cdda43a60f.json
# ✅ Google Cloud Translate client initialized
# 📋 Using source file: lexicon_french_to_english_20251103_191317.csv
# 📋 Loaded dataset with 6963 rows from lexicon_french_to_english_20251103_191317.csv
# ✅ Found 'English_Translation' column with 6963 entries
# 🔗 Using English translations from French as source for Tsonga translation
# 🔤 Found 6854 English words to translate
# 📊 These are derived from French-to-English translations
#
# 🚀 Starting translation process...
# ⏳ This may take a few minutes depending on the number of words...
# 📝 Translating batch 1: words 1-50 of 6854
#    ✅ Batch 1 completed successfully
# 📝 Translating batch 2: words 51-100 of 6854
#    ✅ Batch 2 completed successfully
# 📝 Translating batch 3: words 101-150 of 6854
#    ✅ Batch 3 completed successfully
# 📝 Translating batch 4: words 151-200 of 6854
#    ✅ Batch 4 completed successfully
# 📝 Translating batch 5: words 201-250 of 6854
#    ✅ Batch 5 completed successfully
# 📝 Translating batch 6: words 251-300 of 6854
#    ✅ Batch 6 completed successfully
# 📝 Translating batch 7: words 301-350 of 6854
#    ✅ Batch 7 completed successfully
# 📝 Translating batch 8: words 351-400 of 6854
#    ✅ Batch 8 completed successfully
# 📝 Translating batch 9: words 401-450 of 6854
#    ✅ Batch 9 completed successfully
# 📝 Translating batch 10: words 451-500 of 6854
#    ✅ Batch 10 completed successfully
# 📝 Translating batch 11: words 501-550 of 6854
#    ✅ Batch 11 completed successfully
# 📝 Translating batch 12: words 551-600 of 6854
#    ✅ Batch 12 completed successfully
# 📝 Translating batch 13: words 601-650 of 6854
#    ✅ Batch 13 completed successfully
# 📝 Translating batch 14: words 651-700 of 6854
#    ✅ Batch 14 completed successfully
# 📝 Translating batch 15: words 701-750 of 6854
#    ✅ Batch 15 completed successfully
# 📝 Translating batch 16: words 751-800 of 6854
#    ✅ Batch 16 completed successfully
# 📝 Translating batch 17: words 801-850 of 6854
#    ✅ Batch 17 completed successfully
# 📝 Translating batch 18: words 851-900 of 6854
#    ✅ Batch 18 completed successfully
# 📝 Translating batch 19: words 901-950 of 6854
#    ✅ Batch 19 completed successfully
# 📝 Translating batch 20: words 951-1000 of 6854
#    ✅ Batch 20 completed successfully
# 📝 Translating batch 21: words 1001-1050 of 6854
#    ✅ Batch 21 completed successfully
# 📝 Translating batch 22: words 1051-1100 of 6854
#    ✅ Batch 22 completed successfully
# 📝 Translating batch 23: words 1101-1150 of 6854
#    ✅ Batch 23 completed successfully
# 📝 Translating batch 24: words 1151-1200 of 6854
#    ✅ Batch 24 completed successfully
# 📝 Translating batch 25: words 1201-1250 of 6854
#    ✅ Batch 25 completed successfully
# 📝 Translating batch 26: words 1251-1300 of 6854
#    ✅ Batch 26 completed successfully
# 📝 Translating batch 27: words 1301-1350 of 6854
#    ✅ Batch 27 completed successfully
# 📝 Translating batch 28: words 1351-1400 of 6854
#    ✅ Batch 28 completed successfully
# 📝 Translating batch 29: words 1401-1450 of 6854
#    ✅ Batch 29 completed successfully
# 📝 Translating batch 30: words 1451-1500 of 6854
#    ✅ Batch 30 completed successfully
# 📝 Translating batch 31: words 1501-1550 of 6854
#    ✅ Batch 31 completed successfully
# 📝 Translating batch 32: words 1551-1600 of 6854
#    ✅ Batch 32 completed successfully
# 📝 Translating batch 33: words 1601-1650 of 6854
#    ✅ Batch 33 completed successfully
# 📝 Translating batch 34: words 1651-1700 of 6854
#    ✅ Batch 34 completed successfully
# 📝 Translating batch 35: words 1701-1750 of 6854
#    ✅ Batch 35 completed successfully
# 📝 Translating batch 36: words 1751-1800 of 6854
#    ✅ Batch 36 completed successfully
# 📝 Translating batch 37: words 1801-1850 of 6854
#    ✅ Batch 37 completed successfully
# 📝 Translating batch 38: words 1851-1900 of 6854
#    ✅ Batch 38 completed successfully
# 📝 Translating batch 39: words 1901-1950 of 6854
#    ✅ Batch 39 completed successfully
# 📝 Translating batch 40: words 1951-2000 of 6854
#    ✅ Batch 40 completed successfully
# 📝 Translating batch 41: words 2001-2050 of 6854
#    ✅ Batch 41 completed successfully
# 📝 Translating batch 42: words 2051-2100 of 6854
#    ✅ Batch 42 completed successfully
# 📝 Translating batch 43: words 2101-2150 of 6854
#    ✅ Batch 43 completed successfully
# 📝 Translating batch 44: words 2151-2200 of 6854
#    ✅ Batch 44 completed successfully
# 📝 Translating batch 45: words 2201-2250 of 6854
#    ✅ Batch 45 completed successfully
# 📝 Translating batch 46: words 2251-2300 of 6854
#    ✅ Batch 46 completed successfully
# 📝 Translating batch 47: words 2301-2350 of 6854
#    ✅ Batch 47 completed successfully
# 📝 Translating batch 48: words 2351-2400 of 6854
#    ✅ Batch 48 completed successfully
# 📝 Translating batch 49: words 2401-2450 of 6854
#    ✅ Batch 49 completed successfully
# 📝 Translating batch 50: words 2451-2500 of 6854
#    ✅ Batch 50 completed successfully
# 📝 Translating batch 51: words 2501-2550 of 6854
#    ✅ Batch 51 completed successfully
# 📝 Translating batch 52: words 2551-2600 of 6854
#    ✅ Batch 52 completed successfully
# 📝 Translating batch 53: words 2601-2650 of 6854
#    ✅ Batch 53 completed successfully
# 📝 Translating batch 54: words 2651-2700 of 6854
#    ✅ Batch 54 completed successfully
# 📝 Translating batch 55: words 2701-2750 of 6854
#    ✅ Batch 55 completed successfully
# 📝 Translating batch 56: words 2751-2800 of 6854
#    ✅ Batch 56 completed successfully
# 📝 Translating batch 57: words 2801-2850 of 6854
#    ✅ Batch 57 completed successfully
# 📝 Translating batch 58: words 2851-2900 of 6854
#    ✅ Batch 58 completed successfully
# 📝 Translating batch 59: words 2901-2950 of 6854
#    ✅ Batch 59 completed successfully
# 📝 Translating batch 60: words 2951-3000 of 6854
#    ✅ Batch 60 completed successfully
# 📝 Translating batch 61: words 3001-3050 of 6854
#    ✅ Batch 61 completed successfully
# 📝 Translating batch 62: words 3051-3100 of 6854
#    ✅ Batch 62 completed successfully
# 📝 Translating batch 63: words 3101-3150 of 6854
#    ✅ Batch 63 completed successfully
# 📝 Translating batch 64: words 3151-3200 of 6854
#    ✅ Batch 64 completed successfully
# 📝 Translating batch 65: words 3201-3250 of 6854
#    ✅ Batch 65 completed successfully
# 📝 Translating batch 66: words 3251-3300 of 6854
#    ✅ Batch 66 completed successfully
# 📝 Translating batch 67: words 3301-3350 of 6854
#    ✅ Batch 67 completed successfully
# 📝 Translating batch 68: words 3351-3400 of 6854
#    ✅ Batch 68 completed successfully
# 📝 Translating batch 69: words 3401-3450 of 6854
#    ✅ Batch 69 completed successfully
# 📝 Translating batch 70: words 3451-3500 of 6854
#    ✅ Batch 70 completed successfully
# 📝 Translating batch 71: words 3501-3550 of 6854
#    ✅ Batch 71 completed successfully
# 📝 Translating batch 72: words 3551-3600 of 6854
#    ✅ Batch 72 completed successfully
# 📝 Translating batch 73: words 3601-3650 of 6854
#    ✅ Batch 73 completed successfully
# 📝 Translating batch 74: words 3651-3700 of 6854
#    ✅ Batch 74 completed successfully
# 📝 Translating batch 75: words 3701-3750 of 6854
#    ✅ Batch 75 completed successfully
# 📝 Translating batch 76: words 3751-3800 of 6854
#    ✅ Batch 76 completed successfully
# 📝 Translating batch 77: words 3801-3850 of 6854
#    ✅ Batch 77 completed successfully
# 📝 Translating batch 78: words 3851-3900 of 6854
#    ✅ Batch 78 completed successfully
# 📝 Translating batch 79: words 3901-3950 of 6854
#    ✅ Batch 79 completed successfully
# 📝 Translating batch 80: words 3951-4000 of 6854
#    ✅ Batch 80 completed successfully
# 📝 Translating batch 81: words 4001-4050 of 6854
#    ✅ Batch 81 completed successfully
# 📝 Translating batch 82: words 4051-4100 of 6854
#    ✅ Batch 82 completed successfully
# 📝 Translating batch 83: words 4101-4150 of 6854
#    ✅ Batch 83 completed successfully
# 📝 Translating batch 84: words 4151-4200 of 6854
#    ✅ Batch 84 completed successfully
# 📝 Translating batch 85: words 4201-4250 of 6854
#    ✅ Batch 85 completed successfully
# 📝 Translating batch 86: words 4251-4300 of 6854
#    ✅ Batch 86 completed successfully
# 📝 Translating batch 87: words 4301-4350 of 6854
#    ✅ Batch 87 completed successfully
# 📝 Translating batch 88: words 4351-4400 of 6854
#    ✅ Batch 88 completed successfully
# 📝 Translating batch 89: words 4401-4450 of 6854
#    ✅ Batch 89 completed successfully
# 📝 Translating batch 90: words 4451-4500 of 6854
#    ✅ Batch 90 completed successfully
# 📝 Translating batch 91: words 4501-4550 of 6854
#    ✅ Batch 91 completed successfully
# 📝 Translating batch 92: words 4551-4600 of 6854
#    ✅ Batch 92 completed successfully
# 📝 Translating batch 93: words 4601-4650 of 6854
#    ✅ Batch 93 completed successfully
# 📝 Translating batch 94: words 4651-4700 of 6854
#    ✅ Batch 94 completed successfully
# 📝 Translating batch 95: words 4701-4750 of 6854
#    ✅ Batch 95 completed successfully
# 📝 Translating batch 96: words 4751-4800 of 6854
#    ✅ Batch 96 completed successfully
# 📝 Translating batch 97: words 4801-4850 of 6854
#    ✅ Batch 97 completed successfully
# 📝 Translating batch 98: words 4851-4900 of 6854
#    ✅ Batch 98 completed successfully
# 📝 Translating batch 99: words 4901-4950 of 6854
#    ✅ Batch 99 completed successfully
# 📝 Translating batch 100: words 4951-5000 of 6854
#    ✅ Batch 100 completed successfully
# 📝 Translating batch 101: words 5001-5050 of 6854
#    ✅ Batch 101 completed successfully
# 📝 Translating batch 102: words 5051-5100 of 6854
#    ✅ Batch 102 completed successfully
# 📝 Translating batch 103: words 5101-5150 of 6854
#    ✅ Batch 103 completed successfully
# 📝 Translating batch 104: words 5151-5200 of 6854
#    ✅ Batch 104 completed successfully
# 📝 Translating batch 105: words 5201-5250 of 6854
#    ✅ Batch 105 completed successfully
# 📝 Translating batch 106: words 5251-5300 of 6854
#    ✅ Batch 106 completed successfully
# 📝 Translating batch 107: words 5301-5350 of 6854
#    ✅ Batch 107 completed successfully
# 📝 Translating batch 108: words 5351-5400 of 6854
#    ✅ Batch 108 completed successfully
# 📝 Translating batch 109: words 5401-5450 of 6854
#    ✅ Batch 109 completed successfully
# 📝 Translating batch 110: words 5451-5500 of 6854
#    ✅ Batch 110 completed successfully
# 📝 Translating batch 111: words 5501-5550 of 6854
#    ✅ Batch 111 completed successfully
# 📝 Translating batch 112: words 5551-5600 of 6854
#    ✅ Batch 112 completed successfully
# 📝 Translating batch 113: words 5601-5650 of 6854
#    ✅ Batch 113 completed successfully
# 📝 Translating batch 114: words 5651-5700 of 6854
#    ✅ Batch 114 completed successfully
# 📝 Translating batch 115: words 5701-5750 of 6854
#    ✅ Batch 115 completed successfully
# 📝 Translating batch 116: words 5751-5800 of 6854
#    ✅ Batch 116 completed successfully
# 📝 Translating batch 117: words 5801-5850 of 6854
#    ✅ Batch 117 completed successfully
# 📝 Translating batch 118: words 5851-5900 of 6854
#    ✅ Batch 118 completed successfully
# 📝 Translating batch 119: words 5901-5950 of 6854
#    ✅ Batch 119 completed successfully
# 📝 Translating batch 120: words 5951-6000 of 6854
#    ✅ Batch 120 completed successfully
# 📝 Translating batch 121: words 6001-6050 of 6854
#    ✅ Batch 121 completed successfully
# 📝 Translating batch 122: words 6051-6100 of 6854
#    ✅ Batch 122 completed successfully
# 📝 Translating batch 123: words 6101-6150 of 6854
#    ✅ Batch 123 completed successfully
# 📝 Translating batch 124: words 6151-6200 of 6854
#    ✅ Batch 124 completed successfully
# 📝 Translating batch 125: words 6201-6250 of 6854
#    ✅ Batch 125 completed successfully
# 📝 Translating batch 126: words 6251-6300 of 6854
#    ✅ Batch 126 completed successfully
# 📝 Translating batch 127: words 6301-6350 of 6854
#    ✅ Batch 127 completed successfully
# 📝 Translating batch 128: words 6351-6400 of 6854
#    ✅ Batch 128 completed successfully
# 📝 Translating batch 129: words 6401-6450 of 6854
#    ✅ Batch 129 completed successfully
# 📝 Translating batch 130: words 6451-6500 of 6854
#    ✅ Batch 130 completed successfully
# 📝 Translating batch 131: words 6501-6550 of 6854
#    ✅ Batch 131 completed successfully
# 📝 Translating batch 132: words 6551-6600 of 6854
#    ✅ Batch 132 completed successfully
# 📝 Translating batch 133: words 6601-6650 of 6854
#    ✅ Batch 133 completed successfully
# 📝 Translating batch 134: words 6651-6700 of 6854
#    ✅ Batch 134 completed successfully
# 📝 Translating batch 135: words 6701-6750 of 6854
#    ✅ Batch 135 completed successfully
# 📝 Translating batch 136: words 6751-6800 of 6854
#    ✅ Batch 136 completed successfully
# 📝 Translating batch 137: words 6801-6850 of 6854
#    ✅ Batch 137 completed successfully
# 📝 Translating batch 138: words 6851-6854 of 6854
#    ✅ Batch 138 completed successfully
#
# ✅ Translation completed! Processed 6854 translations
# 📊 Applying translations to dataset...
# ✅ Successfully translated 6963 out of 6963 entries
# 💾 CSV file saved successfully!
# 📂 Location: lexicon_english_to_tsonga_20251103_191515.csv
# 📊 File contains 6963 rows and 9 columns
#
# 📋 Sample Translation Chain (French → English → Tsonga):
# ----------------------------------------------------------------------
#   Arrange      → Arrange         → Longoloxa
#   Rearrange    → Rearrange       → Hlela hi vuntshwa
#   Parle        → Speak           → Vulavula
#   Reparle      → Speak again     → Vulavula nakambe
#   Remet        → Hand over       → Nyika nyiketa
#   Dis          → Say             → Vula
#   Supperpose   → Superpose       → Ehenhla ka xiyimo xa le henhla
#   Ramasse      → Pick up         → Tlakula
#   Depeche      → News report     → Xiviko xa mahungu
#   Repete       → Repeated        → Ku phindha-phindhiwa
#   ... and 6953 more translations
#
# ============================================================
# 🎉 TRANSLATION CHAIN COMPLETE!
# ✅ French → English → Tsonga translation chain completed
# 💾 Saved CSV file: lexicon_english_to_tsonga_20251103_191515.csv
# 📊 Dataset: 6963 rows, 9 columns
# 🔗 Final CSV contains: French, English, English_Translation, Tsonga_Translation
# ============================================================
